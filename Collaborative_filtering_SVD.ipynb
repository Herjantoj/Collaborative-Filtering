# %% [markdown]
# # Machine Learning for Recommender System - Food Recommender System using SVD

# %%
import numpy as np
import pandas as pd

# %%
# from google.colab import drive
# from google.colab import files

# drive.mount('/content/drive', force_remount=True)

# %%
#https://drive.google.com/file/d/1NNxRmB4rAAmtQwtaPMC4iGRCJbQhnWsI/view?usp=drive_link
#https://drive.google.com/file/d/1q580ZfODqstwFjgNfkPldu3mMkyZ0SzL/view?usp=drive_link

# %%
# !gdown 1NNxRmB4rAAmtQwtaPMC4iGRCJbQhnWsI
# !gdown 1q580ZfODqstwFjgNfkPldu3mMkyZ0SzL
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NNxRmB4rAAmtQwtaPMC4iGRCJbQhnWsI
# To: /content/recipes.csv
# 100% 704M/704M [00:04<00:00, 161MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1q580ZfODqstwFjgNfkPldu3mMkyZ0SzL
# To: /content/reviews.csv
# 100% 496M/496M [00:03<00:00, 138MB/s]

# %%
df_reviews = pd.read_csv('/content/reviews.csv', index_col=False)
df_recipes = pd.read_csv('/content/recipes.csv', index_col=False)

# %%
df_reviews
# Out:
#          ReviewId  RecipeId    AuthorId        AuthorName  Rating  \
# 0               2       992        2008         gayg msft       5
# 1               7      4384        1634     Bill Hilbrich       4
# 2               9      4523        2046  Gay Gilmore ckpt       2
# 3              13      7435        1773     Malarkey Test       5
# 4              14        44        2085        Tony Small       5
# ...           ...       ...         ...               ...     ...
# 1401977   2090339    139499  2002080368       terrylbiggs       2
# 1401978   2090340    148484    41805321        rogerberry       5
# 1401979   2090341    264191  2002901848    Reiketsukan 6.       5
# 1401980   2090345    411791  2002901938            Sue M.       5
# 1401981   2090347    352686  2002812127        dede25cory       5
#
#                                                     Review  \
# 0             better than any you can get at a restaurant!
# ...

# %%
df_recipes
# Out:
#         RecipeId                                              Name  \
# 0             38                 Low-Fat Berry Blue Frozen Dessert
# 1             39                                           Biryani
# 2             40                                     Best Lemonade
# 3             41                    Carina's Tofu-Vegetable Kebabs
# 4             42                                      Cabbage Soup
# ...          ...                                               ...
# 522512    541379                    Meg's Fresh Ginger Gingerbread
# 522513    541380  Roast Prime Rib au Poivre with Mixed Peppercorns
# 522514    541381                             Kirshwasser Ice Cream
# 522515    541382          Quick & Easy Asian Cucumber Salmon Rolls
# 522516    541383                           Spicy Baked Scotch Eggs
#
#           AuthorId      AuthorName CookTime PrepTime TotalTime  \
# 0             1533          Dancer    PT24H    PT45M  PT24H45M
# ...

# %% [markdown]
# ## Filter dataset dengan Date Submitted antara rentang 26 Januari 2000 sampai dengan 31 Desember 2001

# %%
## Filter dataset dengan Date Submitted antara rentang 26 Januari 2000 sampai dengan 31 Desember 2001

df_reviews["DateSubmitted"]= pd.to_datetime(df_reviews["DateSubmitted"])
df_reviews_filtered = df_reviews.loc['2000-01-26':'2001-12-31']

# %%
df_reviews_filtered
# Out:
#         ReviewId  RecipeId  AuthorId AuthorName  Rating  \
# 200000    214331     51721     85528   Starlita       5
# 200001    214332     80170     85528   Starlita       5
# 200002    214333    141258     85528   Starlita       5
# 200003    214334     25677     76074   PCrocker       5
# 200004    214335    133368    130819      Gerry       5
# ...          ...       ...       ...        ...     ...
# 200095    214433    141883    254122   fraxinus       5
# 200096    214434     13882    222037   db8_girl       0
# 200097    214435    132618    254330     ShelEB       5
# 200098    214436     88741    177135  cfletcher       5
# 200099    214437     54087    129958    Bobtail       5
#
#                                                    Review  \
# 200000  I used this recipe to go along with some cherr...
# 200001  I loved this recipe.  The potatoes turned out ...
# 200002  Thanks Cookgirl!\r\nThis recipe was so easy an...
# ...

# %%
# Check NULL
df_reviews_filtered['Rating'].isnull().values.any()
# Out:
# False

# %%
jumlah_voting = len(df_reviews_filtered['AuthorId'])
jumlah_user = df_reviews_filtered['AuthorId'].nunique()
rata2_rating = jumlah_voting / jumlah_user

print("Data dalam rentang waktu 26 Januari 2000 - 31 Desember 2001")
print('Jumlah voting = {}'.format(jumlah_voting))
print('Jumlah user = {}'.format(jumlah_user))
print('rata-rata user melakukan rating = {} / {} = {}'.format(jumlah_voting,jumlah_user, rata2_rating))
# Out:
# Data dalam rentang waktu 26 Januari 2000 - 31 Desember 2001
# Jumlah voting = 100
# Jumlah user = 76
# rata-rata user melakukan rating = 100 / 76 = 1.3157894736842106

# %% [markdown]
# ## drop column

# %%
# Drop attribut yang tidak akan digunakan
df_reviews_filtered.drop("AuthorName", axis=1, inplace=True)
df_reviews_filtered.drop("DateSubmitted", axis=1, inplace=True)
df_reviews_filtered.drop("DateModified", axis=1, inplace=True)
df_reviews_filtered.drop("ReviewId", axis=1, inplace=True)
df_reviews_filtered.drop("Review", axis=1, inplace=True)
# Out:
# <ipython-input-12-be0a7fd48333>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews_filtered.drop("AuthorName", axis=1, inplace=True)
# <ipython-input-12-be0a7fd48333>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews_filtered.drop("DateSubmitted", axis=1, inplace=True)
# <ipython-input-12-be0a7fd48333>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_reviews_filtered
# Out:
#         RecipeId  AuthorId  Rating
# 200000     51721     85528       5
# 200001     80170     85528       5
# 200002    141258     85528       5
# 200003     25677     76074       5
# 200004    133368    130819       5
# ...          ...       ...     ...
# 200095    141883    254122       5
# 200096     13882    222037       0
# 200097    132618    254330       5
# 200098     88741    177135       5
# 200099     54087    129958       5
#
# [100 rows x 3 columns]

# %% [markdown]
# # Algortima SVD

# %%
# !pip install scikit-surprise

# %%
from surprise import accuracy, Dataset, SVD, Reader
from surprise.model_selection import KFold

# %%
data = Dataset.load_from_df(df_reviews_filtered, Reader())

# %%
# define a cross-validation iterator
kf = KFold(n_splits=5)

algo = SVD()

for i, (trainset, testset) in enumerate(kf.split(data)):

    # train and test algorithm.
    algo.fit(trainset)
    # predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    print(f"RMSE for fold {i + 1}: {accuracy.rmse(algo.test(testset), verbose=True)}")
    print(f"MSE for fold {i + 1}: {accuracy.mse(algo.test(testset), verbose=True)}")
# Out:
# RMSE: 0.6979
# RMSE for fold 1: 0.6978718223131698
# MSE: 0.4870
# MSE for fold 1: 0.48702508037870446
# RMSE: 0.4648
# RMSE for fold 2: 0.4647910785946015
# MSE: 0.2160
# MSE for fold 2: 0.21603074674113304
# RMSE: 1.1113
# RMSE for fold 3: 1.1113054678442718
# MSE: 1.2350
# MSE for fold 3: 1.2349998428605757
# RMSE: 0.9017
# RMSE for fold 4: 0.9016808483688044
# MSE: 0.8130
# MSE for fold 4: 0.8130283523150867
# RMSE: 1.1795
# RMSE for fold 5: 1.1795387885876065
# MSE: 1.3913
# MSE for fold 5: 1.3913117537827184

# %% [markdown]
# # Rekomendasi food untuk Specific User

# %%
# Predict userId = 85528 dengan recipe id = 51721
algo.predict(85528, "51721")
# Out:
# Prediction(uid=85528, iid='51721', r_ui=None, est=4.6875, details={'was_impossible': False})

# %%
# Userid = 85528

# %%
# total recipe yang ada di dataset
all_recipe = pd.DataFrame(df_reviews_filtered['RecipeId'].unique(), columns=['RecipeId']) #jumlah film
all_recipe
# Out:
#     RecipeId
# 0      51721
# 1      80170
# 2     141258
# 3      25677
# 4     133368
# ..       ...
# 92    141883
# 93     13882
# 94    132618
# 95     88741
# 96     54087
#
# [97 rows x 1 columns]

# %%
all_recipe.nunique()
# Out:
# RecipeId    97
# dtype: int64

# %%
# recipe apa saja yang sudah dirating oleh AuthorId = 85528
rated = df_reviews_filtered[df_reviews_filtered.AuthorId == 85528]
rated.head()
# Out:
#         RecipeId  AuthorId  Rating
# 200000     51721     85528       5
# 200001     80170     85528       5
# 200002    141258     85528       5

# %%
print('Recipe yang sudah dirating oleh user 85528 = {}'.format(rated['RecipeId'].nunique()))
# Out:
# Recipe yang sudah dirating oleh user 85528 = 3

# %%
# Recipe yang belum di rating oleh AuthorId 85528
rated_list = pd.Series(rated['RecipeId'])
not_rated = all_recipe['RecipeId'].isin( rated_list)
not_rated = all_recipe[~not_rated]
not_rated.reset_index(inplace=True)
not_rated.drop(['index'], axis=1, inplace=True)
not_rated.head()
# Out:
# <ipython-input-24-8c9aafc32ea6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_rated.drop(['index'], axis=1, inplace=True)
#    RecipeId
# 0     25677
# 1    133368
# 2     93407
# 3     15788
# 4    113736

# %% [markdown]
# # Predict and Recomendation

# %%
author_id = 85528

# %%
# prediksi rating author dengan id 85528
score = pd.DataFrame([algo.predict(author_id, x).est for x in not_rated['RecipeId']], columns=['rating'])
score.head()
# Out:
#    rating
# 0  4.6875
# 1  4.6875
# 2  4.6875
# 3  4.6875
# 4  4.6875

# %% [markdown]
# ## Top-10 food recommendations (recipes) for Author with ID 85528

# %%
result = not_rated.join(score['rating']).sort_values(by='rating', ascending=False)
result.head(10)
# Out:
#     RecipeId  rating
# 0      25677  4.6875
# 59     17248  4.6875
# 68     74839  4.6875
# 67    136909  4.6875
# 66     32735  4.6875
# 65     63756  4.6875
# 64    128989  4.6875
# 63     17225  4.6875
# 62    134287  4.6875
# 61     90827  4.6875
